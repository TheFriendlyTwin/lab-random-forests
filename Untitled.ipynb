# %% [markdown]
# # Lab | Random Forests

# %% [markdown]
# -------------------------------------------------------------------------------------------
# For this lab, you will be using the CSV files provided in the files_for_lab folder.
#
# --------------------------------------------------------------------------------------------

# %%
#Importing necessary libraries
import pandas as pd
import numpy as np

# %%
#Importing the csv file into a varieble
df_target = pd.read_csv(r"C:\Users\mafal\Documents\ironhack\labs\lab-random-forests\files_for_lab\target.csv")

# %%
df_target
# Out:
#        TARGET_B  TARGET_D
# 0             0       0.0
# 1             0       0.0
# 2             0       0.0
# 3             0       0.0
# 4             0       0.0
# ...         ...       ...
# 95407         0       0.0
# 95408         0       0.0
# 95409         0       0.0
# 95410         1      18.0
# 95411         0       0.0
#
# [95412 rows x 2 columns]

# %%
#Importing the numerical csv file into a varieble
df_numerical = pd.read_csv(r"C:\Users\mafal\Documents\ironhack\labs\lab-random-forests\files_for_lab\numerical.csv")
df_numerical
# Out:
#        TCODE        AGE  INCOME  WEALTH1  HIT  MALEMILI  MALEVET  VIETVETS  \
# 0          0  60.000000       5        9    0         0       39        34
# 1          1  46.000000       6        9   16         0       15        55
# 2          1  61.611649       3        1    2         0       20        29
# 3          0  70.000000       1        4    2         0       23        14
# 4          0  78.000000       3        2   60         1       28         9
# ...      ...        ...     ...      ...  ...       ...      ...       ...
# 95407      1  61.611649       5        9    0        14       36        47
# 95408      1  48.000000       7        9    1         0       31        43
# 95409      1  60.000000       5        9    0         0       18        46
# 95410      0  58.000000       7        9    0         0       28        35
# 95411      2  80.000000       5        8    3         1       33        22
#
# ...

# %%
#Importing the categorical csv file into a varieble
df_categorical = pd.read_csv(r"C:\Users\mafal\Documents\ironhack\labs\lab-random-forests\files_for_lab\categorical.csv")
df_categorical
# Out:
#        STATE  CLUSTER HOMEOWNR GENDER  DATASRCE RFA_2R RFA_2A GEOCODE2  \
# 0         IL       36        H      F         3      L      E        C
# 1         CA       14        H      M         3      L      G        A
# 2         NC       43        U      M         3      L      E        C
# 3         CA       44        U      F         3      L      E        C
# 4         FL       16        H      F         3      L      F        A
# ...      ...      ...      ...    ...       ...    ...    ...      ...
# 95407  other       27        H      M         3      L      G        C
# 95408     TX       24        H      M         3      L      F        A
# 95409     MI       30        H      M         3      L      E        B
# 95410     CA       24        H      F         2      L      F        A
# 95411     NC       24        U      F         3      L      G        C
#
#       DOMAIN_A  DOMAIN_B  ...  DOB_YR  DOB_MM  MINRDATE_YR  MINRDATE_MM  \
# ...

# %% [markdown]
# ### Instructions

# %% [markdown]
# ##### 1. Apply the Random Forests algorithm but this time only by upscaling the data using SMOTE.

# %%
import warnings
warnings.filterwarnings('ignore')

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV

# %%
df_target_copy = df_target.copy()

X = pd.get_dummies(df_target_copy.drop(columns=['TARGET_B', 'TARGET_D']))
y = df_target_copy['TARGET_B']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 3
#       1 df_target_copy = df_target.copy()
# ----> 3 X = pd.get_dummies(df_target_copy.drop(columns=['TARGET_B', 'TARGET_D']))
#       4 y = df_target_copy['TARGET_B']
#       6 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\encoding.py:213, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     203         dummy = _get_dummies_1d(
#     204             col[1],
#     205             prefix=pre,
#    (...)
#     210             dtype=dtype,
#     211         )
#     212         with_dummies.append(dummy)
# --> 213     result = concat(with_dummies, axis=1)
#     214 else:
#     215     result = _get_dummies_1d(
#     216         data,
#     217         prefix,
#    (...)
# ...

# %% [markdown]
# ##### 2. Note that since SMOTE works on numerical data only, we will first encode the categorical variables in this case.
